# %%
# !python landmark.py --video-path "/home/duy1332002/Desktop/Lip_Reading_THDH/preprocessing/ảnh_0001.mp4/ảnh_0001.mp4.mp4" --save-landmark True --dir-save-landmark "/home/duy1332002/Desktop/Lip_Reading_THDH/preprocessing/save_landmark"
# Out:
# Video name: ảnh_0001.mp4.mp4, frame width: 406, frame height: 720, frame rate: 30.0, frame count: 6
# Took 87.67ms (detect: 6.90ms, crop: 0.97ms, track: 8.12ms, 3D points: 71.65ms)
# Took 11.29ms (detect: 0.00ms, crop: 0.40ms, track: 9.78ms, 3D points: 1.10ms)
# Took 11.90ms (detect: 0.00ms, crop: 0.69ms, track: 10.16ms, 3D points: 1.02ms)
# Took 11.70ms (detect: 0.00ms, crop: 0.76ms, track: 10.03ms, 3D points: 0.90ms)
# Took 8.77ms (detect: 0.00ms, crop: 0.58ms, track: 7.21ms, 3D points: 0.96ms)
# Took 8.58ms (detect: 0.00ms, crop: 0.61ms, track: 7.26ms, 3D points: 0.70ms)
# Took 8.80ms (detect: 0.00ms, crop: 0.62ms, track: 7.40ms, 3D points: 0.76ms)
# Took 8.83ms (detect: 0.00ms, crop: 0.60ms, track: 7.40ms, 3D points: 0.82ms)
# Took 8.84ms (detect: 0.00ms, crop: 0.57ms, track: 7.36ms, 3D points: 0.88ms)
# Took 8.48ms (detect: 0.00ms, crop: 0.59ms, track: 7.16ms, 3D points: 0.72ms)
# Took 10.50ms (detect: 0.00ms, crop: 0.86ms, track: 8.77ms, 3D points: 0.83ms)
# ...

# %%
# !python crop_mouth_from_video.py --video-direc "ảnh_0001" --landmark-direc "/home/duy1332002/Desktop/Lip_Reading_THDH/preprocessing/save_landmark" --save-direc "/home/duy1332002/Desktop/Lip_Reading_THDH/preprocessing/visual_data" --filename-path "/home/duy1332002/Desktop/Lip_Reading_THDH/preprocessing/test.csv" --convert-gray
# Out:
# idx: 0 	Processing.	ảnh_0001.mp4

# %%
import numpy as np

t = np.load("/home/duy1332002/Desktop/Lip_Reading_THDH/preprocessing/visual_data/ảnh_0001.mp4.npz")

# %%
import matplotlib.pyplot as plt

#show 6 images
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.title("image "+str(i+1))
    plt.imshow(t["data"][i], cmap='gray')
